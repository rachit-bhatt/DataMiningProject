# %% [markdown]
# <center><font color = '#F88158'><h1>⛹🏻‍♂️NATIONAL BASKETB🏀LL ASSOCIATION⛹️‍♂️</h1></font></center>

# %% [markdown]
# # External Dependencies

# %%
# Data Manipulation
from pandas import read_csv

# %% [markdown]
# # Data Mining

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
# Loading the dataset for exploration.
df = read_csv('Data/data4.csv')

# %%
# First look on the dataset.
df
# Out:
#          gameid        date     type      teamid team home away   MIN  \
# 0      29600001  1996-11-01  regular  1610612738  BOS  BOS  CHI  48.0
# 1      29600001  1996-11-01  regular  1610612741  CHI  BOS  CHI  48.0
# 2      29600002  1996-11-01  regular  1610612751  NJN  NJN  CLE  48.0
# 3      29600002  1996-11-01  regular  1610612739  CLE  NJN  CLE  48.0
# 4      29600003  1996-11-01  regular  1610612749  MIL  PHI  MIL  48.0
# ...         ...         ...      ...         ...  ...  ...  ...   ...
# 68123  42200403  2023-06-07  playoff  1610612743  DEN  MIA  DEN  48.0
# 68124  42200404  2023-06-09  playoff  1610612748  MIA  MIA  DEN  48.0
# 68125  42200404  2023-06-09  playoff  1610612743  DEN  MIA  DEN  48.0
# 68126  42200405  2023-06-12  playoff  1610612743  DEN  DEN  MIA  48.0
# 68127  42200405  2023-06-12  playoff  1610612748  MIA  DEN  MIA  48.0
#
#        %FGA 2PT  %FGA 3PT  ...  %PTS OFF TO  %PTS PITP  2FGM %AST  2FGM %UAST  \
# ...

# %% [markdown]
# #### Observations:
# 1. So, the data contains ID fields which should be removed - *gameid* and *teamid*.
# 2. Also, the *date* could be set as an index for the time-series analysis.

# %% [markdown]
# ### Statistical Analysis

# %%
# Determining the datatypes with the value-count.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68128 entries, 0 to 68127
# Data columns (total 25 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   gameid       68128 non-null  int64
#  1   date         68128 non-null  object
#  2   type         68128 non-null  object
#  3   teamid       68128 non-null  int64
#  4   team         68128 non-null  object
#  5   home         68128 non-null  object
#  6   away         68128 non-null  object
#  7   MIN          68128 non-null  float64
#  8   %FGA 2PT     68128 non-null  float64
#  9   %FGA 3PT     68128 non-null  float64
#  10  %PTS 2PT     68128 non-null  float64
#  11  %PTS 2PT MR  68128 non-null  float64
#  12  %PTS 3PT     68128 non-null  float64
#  13  %PTS FBPS    68128 non-null  float64
#  14  %PTS FT      68128 non-null  float64
#  15  %PTS OFF TO  68128 non-null  float64
#  16  %PTS PITP    68128 non-null  float64
#  17  2FGM %AST    68128 non-null  float64
# ...

# %%
# Statistical Data Analysis.
df.describe()
# Out:
#              gameid        teamid           MIN      %FGA 2PT      %FGA 3PT  \
# count  6.812800e+04  6.812800e+04  68128.000000  68128.000000  68128.000000
# mean   2.356169e+07  1.610613e+09     48.353762     74.610019     25.392494
# std    5.789194e+06  8.600162e+00      1.495026     10.455343     10.455169
# min    2.000000e+07  1.610613e+09     47.400000     30.800000      0.000000
# 25%    2.070007e+07  1.610613e+09     48.000000     67.700000     17.600000
# 50%    2.140022e+07  1.610613e+09     48.000000     75.900000     24.100000
# 75%    2.210044e+07  1.610613e+09     48.000000     82.400000     32.300000
# max    5.220021e+07  1.610613e+09     68.000000    100.000000     69.200000
#
#            %PTS 2PT   %PTS 2PT MR      %PTS 3PT     %PTS FBPS       %PTS FT  \
# count  68128.000000  68128.000000  68128.000000  68128.000000  68128.000000
# mean      59.897751     18.507107     21.887447     12.727501     18.216128
# ...

# %% [markdown]
# ## Missing Values

# %% [markdown]
# ## Missing Values Operation

# %% [markdown]
# ## Outlier Detection

# %% [markdown]
# ## Outlier Operation

# %% [markdown]
# # Machine Learning

# %% [markdown]
# # Data Visualization
